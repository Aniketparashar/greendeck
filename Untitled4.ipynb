# %%
from google.colab import files 
  
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-45253883-35b4-43bd-8120-af4fd9286814" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-45253883-35b4-43bd-8120-af4fd9286814">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Hourly-train.csv to Hourly-train.csv

# %%
import pandas as pd 
import io 
  
df = pd.read_csv(io.BytesIO(uploaded['Hourly-train.csv'])) 
print(df)
# Out:
#        V1      V2      V3      V4      V5  ...   V957  V958  V959  V960  V961
# 0      H1   605.0   586.0   586.0   559.0  ...    NaN   NaN   NaN   NaN   NaN
# 1      H2  3124.0  2990.0  2862.0  2809.0  ...    NaN   NaN   NaN   NaN   NaN
# 2      H3  1828.0  1806.0  1897.0  1750.0  ...    NaN   NaN   NaN   NaN   NaN
# 3      H4  6454.0  6324.0  6075.0  5949.0  ...    NaN   NaN   NaN   NaN   NaN
# 4      H5  4263.0  4297.0  4236.0  4080.0  ...    NaN   NaN   NaN   NaN   NaN
# ..    ...     ...     ...     ...     ...  ...    ...   ...   ...   ...   ...
# 409  H410   153.0   196.0   163.0   131.0  ...  108.0  70.0  72.0  79.0  77.0
# 410  H411    24.0    30.0    22.0    14.0  ...   76.0  66.0  67.0  51.0  42.0
# 411  H412    19.0    30.0    12.0    16.0  ...   71.0  70.0  73.0  39.0  36.0
# 412  H413    21.0    16.0    17.0    19.0  ...   59.0  58.0  53.0  38.0  46.0
# 413  H414    15.0    13.0    13.0    16.0  ...   48.0  41.0  35.0  26.0  17.0
#
# [414 rows x 961 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# create a scaler object
scaler = MinMaxScaler()
df_num = df.select_dtypes(include=[np.float])
# fit and transform the data
df_norm = pd.DataFrame(scaler.fit_transform(df_num), columns=df_num.columns)

df_norm.mean()
df_norm=df_norm.fillna(df_norm.mean())
df_norm
from numpy import log
df_norm = log(df_norm)
df_norm

window_size = 100
N = df_norm.size

run_avg_predictions = []
run_avg_x = []

mse_errors = []

running_mean = 0.0
run_avg_predictions.append(running_mean)

decay = 0.5

for pred_idx in range(1,N):

    running_mean = running_mean*decay + (1.0-decay)*df_norm[pred_idx-1]
    run_avg_predictions.append(running_mean)
    mse_errors.append((run_avg_predictions[-1]-df_norm[pred_idx])**2)
    run_avg_x.append(date)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log
#             V2         V3         V4  ...      V959      V960      V961
# 0    -6.917471  -6.927922  -6.900519  ... -2.335889 -2.645522 -3.739848
# 1    -5.262369  -5.284351  -5.300851  ... -2.335889 -2.645522 -3.739848
# 2    -5.800540  -5.790712  -5.713883  ... -2.335889 -2.645522 -3.739848
# 3    -4.535128  -4.533505  -4.546337  ... -2.335889 -2.645522 -3.739848
# 4    -4.950652  -4.920687  -4.907616  ... -2.335889 -2.645522 -3.739848
# ..         ...        ...        ...  ...       ...       ...       ...
# 409  -8.343188  -8.058283  -8.226189  ... -1.449213 -1.516054 -2.453821
# 410 -10.666975 -10.288297 -10.771720  ... -1.537924 -2.063693 -3.230619
# 411 -11.108808 -10.288297 -12.563480  ... -1.432378 -2.438387 -3.455442
# 412 -10.908137 -11.492270 -11.310717  ... -1.838678 -2.477001 -3.104666
# ...
